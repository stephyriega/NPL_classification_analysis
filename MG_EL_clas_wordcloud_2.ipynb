# %%
#Paquetes a utilizar
import pandas as pd
import numpy as np
from pandas import ExcelWriter  
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import spacy
from spacy import displacy
nlp = spacy.load("es_core_news_lg")
pd.options.display.max_colwidth = 300

# %%
d={}
#respuestas clasificadas por primera ronda del algoritmo
excel_writer1 = pd.ExcelWriter('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\outputs\\Open Questions - Endline\\ra_clasificadas_2.xlsx')
#tabla resumen de las respuestas clasificadas por primra ronda del algoritmo
excel_writer2 = pd.ExcelWriter('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\outputs\\Open Questions - Endline\\ra_clasificadas_sum_2.xlsx')
#tabla resumen de las repeticiones de clasificacion de las respuestas clasificadas por primra ronda del algoritmo
excel_writer3 = pd.ExcelWriter('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\outputs\\Open Questions - Endline\\ra_clasificadas_repeated_2.xlsx')
#respuestas clasificadas como ambiguas 
excel_writer4 = pd.ExcelWriter('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\outputs\\Open Questions - Endline\\ra_clasificadas_re_2.xlsx')
#tabla resumen de las repeticiones de clasificacion de las respuestas clasificadas por primra ronda del algoritmo
excel_writer5 = pd.ExcelWriter('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\outputs\\Open Questions - Endline\\ra_clasificadas_b1_2.xlsx') 
#tabla resumen de la comparación de clasificadas por algoritmo y por encuestadoras
#excel_writer6 = pd.ExcelWriter('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\outputs\\Open Questions - Endline\\ra_clasificadas_comp_2.xlsx') 
#respuestas clasificadas por algoritmo y manualmente
excel_writer7 = pd.ExcelWriter('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\outputs\\Open Questions - Endline\\ra_clasificadas_final_2.xlsx') 
  
    
for i in range(1,4):
    #importamos bases
    df_i = pd.read_excel ('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\raw\\Open Questions - Endline\\Endline GM ES_prep_ra.xlsx', sheet_name="ra_{0}".format(i))
    eti_i = pd.read_excel ('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\raw\\Open Questions - Endline\\etiquetas_2.xlsx', sheet_name="ra_{0}".format(i))
    #convertimos a minusculas
    df_i["ra_{0}".format(i)]=df_i["ra_{0}".format(i)].str.lower()
    #eliminamos tildes
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"-", " ")
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"á", "a")
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"é", "e")
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"í", "i")
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"ó", "o")
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"ú", "u")
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"Á", "A")
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"É", "E")
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"Í", "I")
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"Ó", "O")
    df_i["ra_{0}".format(i)] = df_i["ra_{0}".format(i)].replace(u"Ú", "U")
    #Bucle que recorre cada palabra clave de las etiquetas y codifica
    df_i['codigo']= df_i["ra_{0}".format(i)]
    #nested loop
    #rango de palabras para la categoria 1: mentalidad neutral
    for j in range(0,15):
          df_i['codigo'] = np.where(df_i["ra_{0}".format(i)].str.contains(eti_i['Lista'][j]), '1', df_i['codigo'])
        #rango de palabras para la categoria 2: mentalidad fija
    for j in range(16,35):
          df_i['codigo'] = np.where(df_i["ra_{0}".format(i)].str.contains(eti_i['Lista'][j]), '2', df_i['codigo'])
        #rango de palabras para la categoria 3: mentalidad de crecimiento
    for j in range(36,108):
          df_i['codigo'] = np.where(df_i["ra_{0}".format(i)].str.contains(eti_i['Lista'][j]), '3', df_i['codigo'])
    
    #creamos columnas individuales
    df_i['codigo1']=df_i["ra_{0}".format(i)]
    df_i['codigo2']=df_i["ra_{0}".format(i)]
    df_i['codigo3']=df_i["ra_{0}".format(i)]
    
    #asignamos a a cada columna individual
    
    for j in range(0,15):
          df_i['codigo3'] = np.where(df_i["ra_{0}".format(i)].str.contains(eti_i['Lista'][j]), '0' , '0')
    for j in range(16,35):
          df_i['codigo2'] = np.where(df_i["ra_{0}".format(i)].str.contains(eti_i['Lista'][j]), '0' , '0')
    #rango de palabras para la categoria 3
    for j in range(36,108):
          df_i['codigo1'] = np.where(df_i["ra_{0}".format(i)].str.contains(eti_i['Lista'][j]), '0' , '0')

    for j in range(0,15):
          df_i['codigo3'] = np.where(df_i["ra_{0}".format(i)].str.contains(eti_i['Lista'][j]), '1' , df_i['codigo3'] )
    for j in range(16,35):
          df_i['codigo2'] = np.where(df_i["ra_{0}".format(i)].str.contains(eti_i['Lista'][j]), '1' , df_i['codigo2'] )
    #rango de palabras para la categoria 3
    for j in range(36,108):
          df_i['codigo1'] = np.where(df_i["ra_{0}".format(i)].str.contains(eti_i['Lista'][j]), '1' , df_i['codigo1'] )

    #convertimos a float
    df_i['codigo1'] = df_i['codigo1'].astype(int)
    df_i['codigo2'] = df_i['codigo2'].astype(int)
    df_i['codigo3'] = df_i['codigo3'].astype(int)

    #sumamos las variables
    df_i['sum'] = df_i['codigo1'] + df_i['codigo2']+ df_i['codigo3']
    #cambiamos los no clasificados por 0 en codigo
    df_i.loc[df_i['sum']== 0, 'codigo']="0"
    
        #exportamos a excel todas las observaciones y su clasificacion (y reclasificacion)
    df_i.to_excel(excel_writer1, sheet_name="ra_{0}".format(i))
        
        #exportamos a excel una tabla resumen con la cantidad de obs clasificadas por tipo mediante la primera etapa del algoritmo
    count_i = df_i.groupby('codigo').size().reset_index(name='obs')
    count_i.to_excel(excel_writer2, sheet_name="ra_{0}".format(i))
    
        #exportamos a excel una tabla resumen con la cantidad de obs clasificadas por cantidad de repeticion
    count_i = df_i.groupby('sum').size().reset_index(name='obs')
    count_i.to_excel(excel_writer3, sheet_name="ra_{0}".format(i))
    
    #nos quedamos con variables de interes
    df_i=df_i[["treatment", "ra_{0}".format(i), "key", "codigo", "sum"]]

    #separamos la base de datos entre aquellas obs con 1 o varias/ninguna categorias
    df_i_b1=df_i[df_i['sum']==1]
    df_i_b2=df_i[df_i['sum']!=1]

    #exportamos a excel las observaciones clasificadas como ambiguas 
    df_i_b2.to_excel(excel_writer4, sheet_name="ra_{0}".format(i))
    
    #exportamos a excel una tabla resumen con la cantidad de obs clasificadas que tienen repeticion de tipo
    count_i = df_i_b1.groupby('codigo').size().reset_index(name='obs')
    count_i.to_excel(excel_writer5, sheet_name="ra_{0}".format(i))
    
    #comparacion entre clasificacion de encuestadoras    
    #importamos lo clasificado por las encuestadoras
    #df_i_c = pd.read_excel ('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\raw\\Open Questions - Endline\\Endline GM ES_prep_ca.xlsx', sheet_name="ca_{0}".format(i), dtype=str)

    #unimos la base de datos con obs ya clasificadas con las q se van a clasificar
    #merge_df_i = pd.merge(df_i_b1, df_i_c, how ="left",indicator=True)
    
    #creamos variable dummy para ver si existe diferencia en clasificacion
    #merge_df_i['com_1'] = (merge_df_i['codigo'] == merge_df_i["ca_{0}".format(i)])*1
    
    #exportamos tabla resumen de variable dummy comparativa
    #count_i= merge_df_i.groupby('com_1').size().reset_index(name='obs')
    #count_i.to_excel(excel_writer6, sheet_name="ca_{0}".format(i))
    
    #Unión y clasificación final
    #importamos las observaciones que eran ambiguas pero fueron clasificadas manualmente
    df_i_re = pd.read_excel ('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\outputs\\Open Questions - Endline\\ra_reclasificadas.xlsx', sheet_name="ra_{0}".format(i))
    
    #mergeamos b1 y re
    df_i_final=pd.concat([df_i_b1, df_i_re])
    
    #exportamos a excel
    df_i_final.to_excel(excel_writer7, sheet_name="ra_{0}".format(i))
    
    #Creación de wordclouds
    #mentalidad del crecimiento
    df_i_mc = df_i_final["ra_{0}".format(i)][df_i['codigo'] == '3']
    df_i_mc_s = df_i_mc.to_string(index = False)
    
    doc_i = nlp(df_i_mc_s)
    filtered_text_i = ' '.join([token.text for token in doc_i if not token.is_stop])
    wordcloud_i = WordCloud().generate(filtered_text_i)
    # Display the generated image:
    plt.figure(figsize=(10,10))
    plt.imshow(wordcloud_i, interpolation='bilinear')
    plt.axis("off")
    plt.show()
    wordcloud_i.to_file('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\outputs\\Open Questions - Endline\\'+"ra_{0}".format(i)+'_mc'+'.png')
    
    #mentalidad fija
    df_i_mf = df_i_final["ra_{0}".format(i)][df_i['codigo'] == '2']  
    df_i_mf_s = df_i_mf.to_string(index = False)
    
    doc_i = nlp(df_i_mf_s)
    filtered_text_i = ' '.join([token.text for token in doc_i if not token.is_stop])
    wordcloud_i = WordCloud().generate(filtered_text_i)
    # Display the generated image:
    plt.figure(figsize=(10,10))
    plt.imshow(wordcloud_i, interpolation='bilinear')
    plt.axis("off")
    plt.show()
    wordcloud_i.to_file('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\outputs\\Open Questions - Endline\\'+"ra_{0}".format(i)+'_mf'+'.png')

excel_writer1.save()
excel_writer2.save()  
excel_writer3.save() 
excel_writer4.save() 
excel_writer5.save()
#excel_writer6.save() 
excel_writer7.save()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 18>()
#      18 for i in range(1,4):
#      19     #importamos bases
#      20     df_i = pd.read_excel ('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\raw\\Open Questions - Endline\\Endline GM ES_prep_ra.xlsx', sheet_name="ra_{0}".format(i))
# ---> 21     eti_i = pd.read_excel ('C:\\Users\\Stephy\\Box\\El Salvador growth mindset\\07_Questionnaires&Data\\Endline_Quant\\03_DataManagement\\05 Data analysis\\raw\\Open Questions - Endline\\etiquetas_2.xlsx', sheet_name="ra_{0}".format(i))
#      22     #convertimos a minusculas
#      23     df_i["ra_{0}".format(i)]=df_i["ra_{0}".format(i)].str.lower()
#
# ...
